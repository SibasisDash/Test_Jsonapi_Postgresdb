# %%
import pandas as pd
from ast import literal_eval
import numpy as np
df = pd.read_json('data.json')


#df.rates = df.rates.fillna({i: {} for i in df.index})  # if the column is not strings

# Convert the column of stringified dicts to dicts
# skip this line, if the column contains dicts
#df.rates = df.rates.apply(literal_eval)

#df = df.join(pd.json_normalize(df.rates))
df = df[['rates']]
#df.drop(columns=['start_at','base','end_at'], inplace=True)
df.index.name = "Date"
#df

# %%
key = ['USD', 'JPY', 'CAD', 'GBP', 'NZD','IND']
key_del = ['IDR','BGN','ILS','DKK','MXN','HUF','RON','MYR','SEK','SGD','HKD','AUD','CHF','KRW','CNY','TRY','HRK','THB','ISK','NOK','RUB','CZK','BRL','PLN','PHP','ZAR']

for i in range(len(df)):
    dict_temp = {}
    new_dict = {}
    to_string = str(df.rates[i])
    dict_temp = eval(to_string)
    new_dict = {key:dict_temp[key] for key in dict_temp.keys() - key_del}
    new_dict['EUR'] = 1
    df.rates[i] = new_dict

# %%
df
# Out:
#                                                         rates
# Date
# 2018-01-02  {'GBP': 0.88953, 'NZD': 1.6955, 'USD': 1.20650...
# 2018-01-03  {'GBP': 0.8864000000000001, 'NZD': 1.6942, 'US...
# 2018-01-04  {'GBP': 0.8910300000000001, 'NZD': 1.6957, 'US...
# 2018-01-05  {'GBP': 0.8888300000000001, 'NZD': 1.6837, 'US...
# 2018-01-08  {'GBP': 0.8841300000000001, 'NZD': 1.6702, 'US...
# ...                                                       ...
# 2020-10-23  {'GBP': 0.9067500000000001, 'NZD': 1.7703, 'US...
# 2020-10-26  {'GBP': 0.9075500000000001, 'NZD': 1.7677, 'US...
# 2020-10-27  {'GBP': 0.9071800000000001, 'NZD': 1.7639, 'US...
# 2020-10-28  {'GBP': 0.9066200000000001, 'NZD': 1.7647, 'US...
# 2020-10-29  {'GBP': 0.9043, 'NZD': 1.7677, 'USD': 1.170399...
#
# [723 rows x 1 columns]

# %%
dft = pd.read_json('data.json')
dft = pd.json_normalize(dft['rates'])
dft['Date'] = df4.index
dft['EUR'] = 1

# %%
dft = dft[['Date','EUR','USD','GBP','INR','CAD','NZD','JPY']]
dft
# Out:
#           Date  EUR     USD      GBP      INR     CAD     NZD     JPY
# 0   2018-01-02    1  1.2065  0.88953  76.6005  1.5128  1.6955  135.35
# 1   2018-01-03    1  1.2023  0.88640  76.3455  1.5047  1.6942  134.97
# 2   2018-01-04    1  1.2065  0.89103  76.4980  1.5114  1.6957  135.92
# 3   2018-01-05    1  1.2045  0.88883  76.3290  1.5068  1.6837  136.45
# 4   2018-01-08    1  1.1973  0.88413  76.0375  1.4880  1.6702  135.34
# ..         ...  ...     ...      ...      ...     ...     ...     ...
# 718 2020-10-23    1  1.1856  0.90675  87.3245  1.5563  1.7703  124.17
# 719 2020-10-26    1  1.1819  0.90755  87.5485  1.5580  1.7677  124.14
# 720 2020-10-27    1  1.1832  0.90718  87.1635  1.5589  1.7639  123.74
# 721 2020-10-28    1  1.1727  0.90662  86.8040  1.5578  1.7647  122.36
# 722 2020-10-29    1  1.1704  0.90430  87.0865  1.5658  1.7677  122.09
#
# [723 rows x 8 columns]

# %%
df = pd.read_json('data2.json')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-7983f2e1c585> in <module>
# ----> 1 df = pd.read_json('data2.json')
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ...
